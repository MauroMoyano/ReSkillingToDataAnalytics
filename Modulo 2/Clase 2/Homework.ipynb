# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import csv
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

archivo = open('Emisiones_CO2.csv', 'r')

lector = csv.reader(archivo)

for fila in lector:
    type(fila)
    partes = fila[0].split('|')
    #print(len(partes))
    #print(partes)
    try:
        dicc_emisiones['cod_pais'].append(partes[0])
        dicc_emisiones['nom_pais'].append(partes[1])
        dicc_emisiones['region'].append(partes[2])
        dicc_emisiones['anio'].append(partes[3])
        dicc_emisiones['co2'].append(partes[4])
        dicc_emisiones['co2_percapita'].append(partes[5])
    except IndexError:
        print("rompe")
print(dicc_emisiones)
# Out:
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# rompe
# ...

# %%
for clave in dicc_emisiones:
    while '' in dicc_emisiones[clave]:
        if '' in dicc_emisiones[clave]:
            dicc_emisiones[clave].remove('')

# %%
import pprint
pprint.pprint(dicc_emisiones)
# Out:
# {'anio': ['Año',
#           '1960',
#           '1961',
#           '1962',
#           '1963',
#           '1964',
#           '1965',
#           '1966',
#           '1967',
#           '1968',
#           '1969',
#           '1970',
#           '1971',
#           '1972',
#           '1973',
#           '1974',
#           '1975',
#           '1976',
#           '1977',
#           '1978',
#           '1979',
#           '1980',
#           '1981',
#           '1982',
#           '1983',
#           '1984',
#           '1985',
#           '1986',
#           '1987',
#           '1988',
#           '1989',
#           '1990',
#           '1991',
#           '1992',
#           '1993',
#           '1994',
#           '1995',
#           '1996',
#           '1997',
#           '1998',
#           '1999',
#           '2000',
#           '2001',
#           '2002',
#           '2003',
#           '2004',
#           '2005',
#           '2006',
#           '2007',
#           '2008',
# ...

# %%
if '' not in dicc_emisiones['cod_pais']:
    print(True)
# Out:
# True

# %%
#Para contar las variables
for clave in dicc_emisiones:
    dicc_emisiones[clave].pop(0)
    newSet = set(dicc_emisiones[clave])
    print("clave", clave , len(newSet))
# Out:
# clave cod_pais 214
# clave nom_pais 214
# clave region 7
# clave anio 52
# clave co2 5095
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[173], line 3
#       1 #Para contar las variables
#       2 for clave in dicc_emisiones:
# ----> 3     dicc_emisiones[clave].pop(0)
#       4     newSet = set(dicc_emisiones[clave])
#       5     print("clave", clave , len(newSet))
#
# IndexError: pop from empty list

# %%
print(len(dicc_emisiones['cod_pais']))
# Out:
# 11127

# %%
listaDeEmisiones = 0.0;
for index, element in enumerate(dicc_emisiones['anio']):
    if '2010' == element and dicc_emisiones['nom_pais'][index].find('Latina y Caribe'):
        #print('entro')
        #print(type(dicc_emisiones['co2'][index]))
        try:
            aux = dicc_emisiones['co2'][index].replace('.','')
            aux = float(aux.replace(',','.'))
        except IndexError:
            x = 0
        #print(aux)
        #emisiones = float(aux)
        listaDeEmisiones += aux
print(listaDeEmisiones)
# Out:
# 16824947.0

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?
